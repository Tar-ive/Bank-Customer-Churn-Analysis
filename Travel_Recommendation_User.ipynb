# %% [markdown]
# <a href="https://colab.research.google.com/github/Tar-ive/Bank-Customer-Churn-Analysis/blob/main/Travel_Recommendation_User.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv("tourism_rating.csv")

# %%
df1.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
df2 = pd.read_csv('package_tourism.csv')

# %%
df2.head()
# Out:
#    Package     City         Place_Tourism1      Place_Tourism2  \
# 0        1  Jakarta      Pasar Tanah Abang        Taman Ayodya
# 1        2  Jakarta      Pasar Tanah Abang  Pasar Taman Puring
# 2        3  Jakarta  Perpustakaan Nasional               Monas
# 3        4  Jakarta           Pulau Tidung      Pulau Bidadari
# 4        5  Jakarta  Museum Satria Mandala       Museum Wayang
#
#           Place_Tourism3                                     Place_Tourism4  \
# 0         Museum Tekstil                                                NaN
# 1   Pasar Petak Sembilan                                                NaN
# 2        Masjid Istiqlal                                                NaN
# 3             Pulau Pari                                      Pulau Pramuka
# 4  Museum Bahari Jakarta  Museum Macan (Modern and Contemporary Art in N...
#
#   Place_Tourism5
# 0            NaN
# 1            NaN
# 2            NaN
# 3  Pulau Pelangi
# 4            NaN

# %%
df3 = pd.read_csv('user.csv')

# %%
df3.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
df4 = pd.read_csv('tourism_with_id.csv')

# %%
df4.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes  \
# 0   20000     4.6          15.0
# 1       0     4.6          90.0
# 2  270000     4.6         360.0
# 3   10000     4.5           NaN
# 4   94000     4.5          60.0
#
# ...

# %%
df1.head()
df2.head()
# Out:
#    Package     City         Place_Tourism1      Place_Tourism2  \
# 0        1  Jakarta      Pasar Tanah Abang        Taman Ayodya
# 1        2  Jakarta      Pasar Tanah Abang  Pasar Taman Puring
# 2        3  Jakarta  Perpustakaan Nasional               Monas
# 3        4  Jakarta           Pulau Tidung      Pulau Bidadari
# 4        5  Jakarta  Museum Satria Mandala       Museum Wayang
#
#           Place_Tourism3                                     Place_Tourism4  \
# 0         Museum Tekstil                                                NaN
# 1   Pasar Petak Sembilan                                                NaN
# 2        Masjid Istiqlal                                                NaN
# 3             Pulau Pari                                      Pulau Pramuka
# 4  Museum Bahari Jakarta  Museum Macan (Modern and Contemporary Art in N...
#
#   Place_Tourism5
# 0            NaN
# 1            NaN
# 2            NaN
# 3  Pulau Pelangi
# 4            NaN

# %%
df1.isna().sum()
df2.isna().sum()
df3.isna().sum()
df4.isna().sum()
# Out:
# Place_Id          0
# Place_Name        0
# Description       0
# Category          0
# City              0
# Price             0
# Rating            0
# Time_Minutes    232
# Coordinate        0
# Lat               0
# Long              0
# Unnamed: 11     437
# Unnamed: 12       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(data=df1, x='Place_Ratings')
plt.show()

# %%
df1.groupby('User_Id')['Place_Ratings'].mean().hist()
plt.show()

# %%
# sns.piechart(data=df2, x='City')
# plt.show()


tourism_cols = ['Place_Tourism1']
df2[tourism_cols].stack().value_counts().plot(kind='bar')

plt.show()

# %%
sns.histplot(data=df3, x='Age')
plt.show()


sns.countplot(data=df3, x='Location')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualize the distribution of categories
sns.countplot(data=df4, x='Category')
plt.xticks(rotation=90)
plt.show()

# Visualize the distribution of prices
sns.histplot(data=df4, x='Price')
plt.show()

# Visualize the distribution of ratings
sns.histplot(data=df4, x='Rating')
plt.show()

# %%
import numpy as np

# %%
merged_df = pd.concat([df1, df2, df3, df4], axis=1)

# %%
merged_df = merged_df.loc[:,~merged_df.columns.duplicated()]

# %%
merged_df.to_csv('merged_file.csv', index=False)

# %%
merged_df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings  Package     City         Place_Tourism1  \
# 0        1       179              3      1.0  Jakarta      Pasar Tanah Abang
# 1        1       344              2      2.0  Jakarta      Pasar Tanah Abang
# 2        1         5              5      3.0  Jakarta  Perpustakaan Nasional
# 3        1       373              3      4.0  Jakarta           Pulau Tidung
# 4        1       101              4      5.0  Jakarta  Museum Satria Mandala
#
#        Place_Tourism2         Place_Tourism3  \
# 0        Taman Ayodya         Museum Tekstil
# 1  Pasar Taman Puring   Pasar Petak Sembilan
# 2               Monas        Masjid Istiqlal
# 3      Pulau Bidadari             Pulau Pari
# 4       Museum Wayang  Museum Bahari Jakarta
#
#                                       Place_Tourism4 Place_Tourism5  ...  \
# 0                                                NaN            NaN  ...
# 1                                                NaN            NaN  ...
# ...

# %%
df = pd.read_csv("merged_file.csv")

# %%
df_sel = df[['Rating', 'Price', 'Location']]

# %%
corr_matrix = df.corr()

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/io/formats/style.py:3555: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.9/dist-packages/pandas/io/formats/style.py:3556: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_a646f_row0_col0, #T_a646f_row0_col10, #T_a646f_row1_col1, #T_a646f_row2_col2, #T_a646f_row2_col10, #T_a646f_row3_col3, #T_a646f_row4_col4, #T_a646f_row5_col5, #T_a646f_row6_col6, #T_a646f_row7_col7, #T_a646f_row8_col8, #T_a646f_row10_col0, #T_a646f_row10_col2, #T_a646f_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a646f_row0_col1, #T_a646f_row1_col3, #T_a646f_row4_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_a646f_row0_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_a646f_row0_col3, #T_a646f_row5_col3, #T_a646f_row7_col1 {
#   background-color: #6384eb;
# ...

# %%
# Check for missing values
print(df.isnull().sum())

# Drop columns with missing values


# Replace missing values with median
df = df.fillna(df.median())
# Out:
# User_Id               5
# Place_Id              0
# Place_Ratings         0
# Package            9900
# City               9903
# Place_Tourism1     9900
# Place_Tourism2     9900
# Place_Tourism3     9900
# Place_Tourism4     9939
# Place_Tourism5     9961
# Location           9705
# Age                9705
# Place_Name         9568
# Description        9568
# Category           9573
# Price              9573
# Rating             9573
# Time_Minutes       9802
# Coordinate         9573
# Lat                9573
# Long               9573
# Unnamed: 11       10005
# Unnamed: 12        9573
# dtype: int64
# <ipython-input-28-44a55c3fcacc>:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.fillna(df.median())

# %%
print(df.isnull().sum())
# Out:
# User_Id               0
# Place_Id              0
# Place_Ratings         0
# Package               0
# City               9903
# Place_Tourism1     9900
# Place_Tourism2     9900
# Place_Tourism3     9900
# Place_Tourism4     9939
# Place_Tourism5     9961
# Location           9705
# Age                   0
# Place_Name         9568
# Description        9568
# Category           9573
# Price                 0
# Rating                0
# Time_Minutes          0
# Coordinate         9573
# Lat                   0
# Long                  0
# Unnamed: 11       10005
# Unnamed: 12           0
# dtype: int64

# %%
df.head()
# Out:
#    User_Id Place_Id  Place_Ratings  Package     City         Place_Tourism1  \
# 0      1.0      179            3.0      1.0  Jakarta      Pasar Tanah Abang
# 1      1.0      344            2.0      2.0  Jakarta      Pasar Tanah Abang
# 2      1.0        5            5.0      3.0  Jakarta  Perpustakaan Nasional
# 3      1.0      373            3.0      4.0  Jakarta           Pulau Tidung
# 4      1.0      101            4.0      5.0  Jakarta  Museum Satria Mandala
#
#        Place_Tourism2         Place_Tourism3  \
# 0        Taman Ayodya         Museum Tekstil
# 1  Pasar Taman Puring   Pasar Petak Sembilan
# 2               Monas        Masjid Istiqlal
# 3      Pulau Bidadari             Pulau Pari
# 4       Museum Wayang  Museum Bahari Jakarta
#
#                                       Place_Tourism4 Place_Tourism5  ...  \
# 0                                                NaN            NaN  ...
# 1                                                NaN            NaN  ...
# ...
